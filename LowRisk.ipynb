# %%
import requests
import pandas as pd
from datetime import datetime, timedelta

API_KEY = ''  # Replace with your actual key

# Get SPY components via FMP ETF holdings endpoint
def get_spy_holdings():
    url = f"https://financialmodelingprep.com/api/v3/etf-holder/SPY?apikey={API_KEY}"
    response = requests.get(url)
    response.raise_for_status()
    holdings = response.json()
    tickers = [item['asset'] for item in holdings if 'asset' in item]
    return list(set(tickers))

# Fetch historical prices for all tickers at once
def fetch_bulk_price_data(tickers, start_date, end_date):
    all_data = {}

    chunk_size = 50  # FMP API limit
    chunks = [tickers[i:i + chunk_size] for i in range(0, len(tickers), chunk_size)]

    for chunk in chunks:
        symbols = ",".join(chunk)
        url = f"https://financialmodelingprep.com/api/v3/historical-price-full/{symbols}?from={start_date}&to={end_date}&apikey={API_KEY}&serietype=line"
        response = requests.get(url)
        response.raise_for_status()
        data = response.json()

        # If only one ticker is returned, wrap it in a list
        if isinstance(data, dict) and 'symbol' in data:
            data = [data]
        elif isinstance(data, dict) and 'historicalStockList' in data:
            data = data['historicalStockList']

        for stock_data in data:
            ticker = stock_data.get("symbol")
            hist = stock_data.get("historical")
            if not hist or not ticker:
                continue
            df = pd.DataFrame(hist)
            df['date'] = pd.to_datetime(df['date'])
            df.set_index('date', inplace=True)
            df.sort_index(inplace=True)
            all_data[ticker] = df['close']

    return pd.DataFrame(all_data).dropna(axis=1)

# %%
# Define backtest window
end_date = datetime.now()
start_date = end_date - timedelta(days=5 * 365)  # Past 5 years
# Backtest period
end_date = datetime.now()
start_date = end_date - timedelta(days=5*365)

# Get SPY tickers and price data
spy_tickers = get_spy_holdings()
price_data = fetch_bulk_price_data(spy_tickers, start_date.strftime('%Y-%m-%d'), end_date.strftime('%Y-%m-%d'))

# Clean index
price_data.index = price_data.index.tz_localize(None)

# Get tickers and download data
excluded_tickers = ['BF-B', 'BRK-B', 'ZBRA']  # Adjusted to FMP-style dashes
tickers = get_sp500_tickers(excluded_tickers)
price_data = build_price_dataset(tickers, start_date.strftime('%Y-%m-%d'), end_date.strftime('%Y-%m-%d'), limit=500)

# Ensure time index is timezone-naive
price_data.index = price_data.index.tz_localize(None)
# Out:
# Fetching 1/500: MMM
# Fetching 2/500: AOS
# Fetching 3/500: ABT
# Fetching 4/500: ABBV
# Fetching 5/500: ACN
# Fetching 6/500: ADBE
# Fetching 7/500: AMD
# Fetching 8/500: AES
# Fetching 9/500: AFL
# Fetching 10/500: A
# Fetching 11/500: APD
# Fetching 12/500: ABNB
# Fetching 13/500: AKAM
# Fetching 14/500: ALB
# Fetching 15/500: ARE
# Fetching 16/500: ALGN
# Fetching 17/500: ALLE
# Fetching 18/500: LNT
# Fetching 19/500: ALL
# Fetching 20/500: GOOGL
# Fetching 21/500: GOOG
# Fetching 22/500: MO
# Fetching 23/500: AMZN
# Fetching 24/500: AMCR
# Fetching 25/500: AEE
# Fetching 26/500: AEP
# Fetching 27/500: AXP
# Fetching 28/500: AIG
# Fetching 29/500: AMT
# Fetching 30/500: AWK
# Fetching 31/500: AMP
# Fetching 32/500: AME
# Fetching 33/500: AMGN
# Fetching 34/500: APH
# Fetching 35/500: ADI
# Fetching 36/500: ANSS
# Fetching 37/500: AON
# Fetching 38/500: APA
# Fetching 39/500: APO
# Fetching 40/500: AAPL
# Fetching 41/500: AMAT
# Fetching 42/500: APTV
# Fetching 43/500: ACGL
# Fetching 44/500: ADM
# Fetching 45/500: ANET
# Fetching 46/500: AJG
# Fetching 47/500: AIZ
# Fetching 48/500: T
# Fetching 49/500: ATO
# Fetching 50/500: ADSK
# Fetching 51/500: ADP
# Fetching 52/500: AZO
# Fetching 53/500: AVB
# Fetching 54/500: AVY
# Fetching 55/500: AXON
# Fetching 56/500: BKR
# Fetching 57/500: BALL
# Fetching 58/500: BAC
# Fetching 59/500: BAX
# Fetching 60/500: BDX
# Fetching 61/500: BBY
# Fetching 62/500: TECH
# Fetching 63/500: BIIB
# Fetching 64/500: BLK
# Fetching 65/500: BX
# Fetching 66/500: BK
# Fetching 67/500: BA
# Fetching 68/500: BKNG
# Fetching 69/500: BSX
# Fetching 70/500: BMY
# Fetching 71/500: AVGO
# Fetching 72/500: BR
# Fetching 73/500: BRO
# Fetching 74/500: BLDR
# Fetching 75/500: BG
# Fetching 76/500: BXP
# Fetching 77/500: CHRW
# Fetching 78/500: CDNS
# Fetching 79/500: CZR
# Fetching 80/500: CPT
# Fetching 81/500: CPB
# Fetching 82/500: COF
# Fetching 83/500: CAH
# Fetching 84/500: KMX
# Fetching 85/500: CCL
# Fetching 86/500: CARR
# Fetching 87/500: CAT
# Fetching 88/500: CBOE
# Fetching 89/500: CBRE
# Fetching 90/500: CDW
# Fetching 91/500: COR
# Fetching 92/500: CNC
# Fetching 93/500: CNP
# Fetching 94/500: CF
# Fetching 95/500: CRL
# Fetching 96/500: SCHW
# Fetching 97/500: CHTR
# Fetching 98/500: CVX
# Fetching 99/500: CMG
# Fetching 100/500: CB
# Fetching 101/500: CHD
# Fetching 102/500: CI
# Fetching 103/500: CINF
# Fetching 104/500: CTAS
# Fetching 105/500: CSCO
# Fetching 106/500: C
# Fetching 107/500: CFG
# Fetching 108/500: CLX
# Fetching 109/500: CME
# Fetching 110/500: CMS
# Fetching 111/500: KO
# Fetching 112/500: CTSH
# Fetching 113/500: COIN
# Fetching 114/500: CL
# Fetching 115/500: CMCSA
# Fetching 116/500: CAG
# Fetching 117/500: COP
# Fetching 118/500: ED
# Fetching 119/500: STZ
# Fetching 120/500: CEG
# Fetching 121/500: COO
# Fetching 122/500: CPRT
# Fetching 123/500: GLW
# Fetching 124/500: CPAY
# Fetching 125/500: CTVA
# Fetching 126/500: CSGP
# Fetching 127/500: COST
# Fetching 128/500: CTRA
# Fetching 129/500: CRWD
# Fetching 130/500: CCI
# Fetching 131/500: CSX
# Fetching 132/500: CMI
# Fetching 133/500: CVS
# Fetching 134/500: DHR
# Fetching 135/500: DRI
# Fetching 136/500: DVA
# Fetching 137/500: DAY
# Fetching 138/500: DECK
# Fetching 139/500: DE
# Fetching 140/500: DELL
# Fetching 141/500: DAL
# Fetching 142/500: DVN
# Fetching 143/500: DXCM
# Fetching 144/500: FANG
# Fetching 145/500: DLR
# Fetching 146/500: DG
# Fetching 147/500: DLTR
# Fetching 148/500: D
# Fetching 149/500: DPZ
# Fetching 150/500: DASH
# Fetching 151/500: DOV
# Fetching 152/500: DOW
# Fetching 153/500: DHI
# Fetching 154/500: DTE
# Fetching 155/500: DUK
# Fetching 156/500: DD
# Fetching 157/500: EMN
# Fetching 158/500: ETN
# Fetching 159/500: EBAY
# Fetching 160/500: ECL
# Fetching 161/500: EIX
# Fetching 162/500: EW
# Fetching 163/500: EA
# Fetching 164/500: ELV
# Fetching 165/500: EMR
# Fetching 166/500: ENPH
# Fetching 167/500: ETR
# Fetching 168/500: EOG
# Fetching 169/500: EPAM
# Fetching 170/500: EQT
# Fetching 171/500: EFX
# Fetching 172/500: EQIX
# Fetching 173/500: EQR
# Fetching 174/500: ERIE
# Fetching 175/500: ESS
# Fetching 176/500: EL
# Fetching 177/500: EG
# Fetching 178/500: EVRG
# Fetching 179/500: ES
# Fetching 180/500: EXC
# Fetching 181/500: EXE
# Fetching 182/500: EXPE
# Fetching 183/500: EXPD
# Fetching 184/500: EXR
# Fetching 185/500: XOM
# Fetching 186/500: FFIV
# Fetching 187/500: FDS
# Fetching 188/500: FICO
# Fetching 189/500: FAST
# Fetching 190/500: FRT
# Fetching 191/500: FDX
# Fetching 192/500: FIS
# Fetching 193/500: FITB
# Fetching 194/500: FSLR
# Fetching 195/500: FE
# Fetching 196/500: FI
# Fetching 197/500: F
# Fetching 198/500: FTNT
# Fetching 199/500: FTV
# Fetching 200/500: FOXA
# Fetching 201/500: FOX
# Fetching 202/500: BEN
# Fetching 203/500: FCX
# Fetching 204/500: GRMN
# Fetching 205/500: IT
# Fetching 206/500: GE
# Fetching 207/500: GEHC
# Fetching 208/500: GEV
# Fetching 209/500: GEN
# Fetching 210/500: GNRC
# Fetching 211/500: GD
# Fetching 212/500: GIS
# Fetching 213/500: GM
# Fetching 214/500: GPC
# Fetching 215/500: GILD
# Fetching 216/500: GPN
# Fetching 217/500: GL
# Fetching 218/500: GDDY
# Fetching 219/500: GS
# Fetching 220/500: HAL
# Fetching 221/500: HIG
# Fetching 222/500: HAS
# Fetching 223/500: HCA
# Fetching 224/500: DOC
# Fetching 225/500: HSIC
# Fetching 226/500: HSY
# Fetching 227/500: HES
# Fetching 228/500: HPE
# Fetching 229/500: HLT
# Fetching 230/500: HOLX
# Fetching 231/500: HD
# Fetching 232/500: HON
# Fetching 233/500: HRL
# Fetching 234/500: HST
# Fetching 235/500: HWM
# Fetching 236/500: HPQ
# Fetching 237/500: HUBB
# Fetching 238/500: HUM
# Fetching 239/500: HBAN
# Fetching 240/500: HII
# Fetching 241/500: IBM
# Fetching 242/500: IEX
# Fetching 243/500: IDXX
# Fetching 244/500: ITW
# Fetching 245/500: INCY
# Fetching 246/500: IR
# Fetching 247/500: PODD
# Fetching 248/500: INTC
# Fetching 249/500: ICE
# Fetching 250/500: IFF
# Fetching 251/500: IP
# Fetching 252/500: IPG
# Fetching 253/500: INTU
# Fetching 254/500: ISRG
# Fetching 255/500: IVZ
# Fetching 256/500: INVH
# Fetching 257/500: IQV
# Fetching 258/500: IRM
# Fetching 259/500: JBHT
# Fetching 260/500: JBL
# Fetching 261/500: JKHY
# Fetching 262/500: J
# Fetching 263/500: JNJ
# Fetching 264/500: JCI
# Fetching 265/500: JPM
# Fetching 266/500: JNPR
# Fetching 267/500: K
# Fetching 268/500: KVUE
# Fetching 269/500: KDP
# Fetching 270/500: KEY
# Fetching 271/500: KEYS
# Fetching 272/500: KMB
# Fetching 273/500: KIM
# Fetching 274/500: KMI
# Fetching 275/500: KKR
# Fetching 276/500: KLAC
# Fetching 277/500: KHC
# Fetching 278/500: KR
# Fetching 279/500: LHX
# Fetching 280/500: LH
# Fetching 281/500: LRCX
# Fetching 282/500: LW
# Fetching 283/500: LVS
# Fetching 284/500: LDOS
# Fetching 285/500: LEN
# Fetching 286/500: LII
# Fetching 287/500: LLY
# Fetching 288/500: LIN
# Fetching 289/500: LYV
# Fetching 290/500: LKQ
# Fetching 291/500: LMT
# Fetching 292/500: L
# Fetching 293/500: LOW
# Fetching 294/500: LULU
# Fetching 295/500: LYB
# Fetching 296/500: MTB
# Fetching 297/500: MPC
# Fetching 298/500: MKTX
# Fetching 299/500: MAR
# Fetching 300/500: MMC
# Fetching 301/500: MLM
# Fetching 302/500: MAS
# Fetching 303/500: MA
# Fetching 304/500: MTCH
# Fetching 305/500: MKC
# Fetching 306/500: MCD
# Fetching 307/500: MCK
# Fetching 308/500: MDT
# Fetching 309/500: MRK
# Fetching 310/500: META
# Fetching 311/500: MET
# Fetching 312/500: MTD
# Fetching 313/500: MGM
# Fetching 314/500: MCHP
# Fetching 315/500: MU
# Fetching 316/500: MSFT
# Fetching 317/500: MAA
# Fetching 318/500: MRNA
# Fetching 319/500: MHK
# Fetching 320/500: MOH
# Fetching 321/500: TAP
# Fetching 322/500: MDLZ
# Fetching 323/500: MPWR
# Fetching 324/500: MNST
# Fetching 325/500: MCO
# Fetching 326/500: MS
# Fetching 327/500: MOS
# Fetching 328/500: MSI
# Fetching 329/500: MSCI
# Fetching 330/500: NDAQ
# Fetching 331/500: NTAP
# Fetching 332/500: NFLX
# Fetching 333/500: NEM
# Fetching 334/500: NWSA
# Fetching 335/500: NWS
# Fetching 336/500: NEE
# Fetching 337/500: NKE
# Fetching 338/500: NI
# Fetching 339/500: NDSN
# Fetching 340/500: NSC
# Fetching 341/500: NTRS
# Fetching 342/500: NOC
# Fetching 343/500: NCLH
# Fetching 344/500: NRG
# Fetching 345/500: NUE
# Fetching 346/500: NVDA
# Fetching 347/500: NVR
# Fetching 348/500: NXPI
# Fetching 349/500: ORLY
# Fetching 350/500: OXY
# Fetching 351/500: ODFL
# Fetching 352/500: OMC
# Fetching 353/500: ON
# Fetching 354/500: OKE
# Fetching 355/500: ORCL
# Fetching 356/500: OTIS
# Fetching 357/500: PCAR
# Fetching 358/500: PKG
# Fetching 359/500: PLTR
# Fetching 360/500: PANW
# Fetching 361/500: PARA
# Fetching 362/500: PH
# Fetching 363/500: PAYX
# Fetching 364/500: PAYC
# Fetching 365/500: PYPL
# Fetching 366/500: PNR
# Fetching 367/500: PEP
# Fetching 368/500: PFE
# Fetching 369/500: PCG
# Fetching 370/500: PM
# Fetching 371/500: PSX
# Fetching 372/500: PNW
# Fetching 373/500: PNC
# Fetching 374/500: POOL
# Fetching 375/500: PPG
# Fetching 376/500: PPL
# Fetching 377/500: PFG
# Fetching 378/500: PG
# Fetching 379/500: PGR
# Fetching 380/500: PLD
# Fetching 381/500: PRU
# Fetching 382/500: PEG
# Fetching 383/500: PTC
# Fetching 384/500: PSA
# Fetching 385/500: PHM
# Fetching 386/500: PWR
# Fetching 387/500: QCOM
# Fetching 388/500: DGX
# Fetching 389/500: RL
# Fetching 390/500: RJF
# Fetching 391/500: RTX
# Fetching 392/500: O
# Fetching 393/500: REG
# Fetching 394/500: REGN
# Fetching 395/500: RF
# Fetching 396/500: RSG
# Fetching 397/500: RMD
# Fetching 398/500: RVTY
# Fetching 399/500: ROK
# Fetching 400/500: ROL
# Fetching 401/500: ROP
# Fetching 402/500: ROST
# Fetching 403/500: RCL
# Fetching 404/500: SPGI
# Fetching 405/500: CRM
# Fetching 406/500: SBAC
# Fetching 407/500: SLB
# Fetching 408/500: STX
# Fetching 409/500: SRE
# Fetching 410/500: NOW
# Fetching 411/500: SHW
# Fetching 412/500: SPG
# Fetching 413/500: SWKS
# Fetching 414/500: SJM
# Fetching 415/500: SW
# Fetching 416/500: SNA
# Fetching 417/500: SOLV
# Fetching 418/500: SO
# Fetching 419/500: LUV
# Fetching 420/500: SWK
# Fetching 421/500: SBUX
# Fetching 422/500: STT
# Fetching 423/500: STLD
# Fetching 424/500: STE
# Fetching 425/500: SYK
# Fetching 426/500: SMCI
# Fetching 427/500: SYF
# Fetching 428/500: SNPS
# Fetching 429/500: SYY
# Fetching 430/500: TMUS
# Fetching 431/500: TROW
# Fetching 432/500: TTWO
# Fetching 433/500: TPR
# Fetching 434/500: TRGP
# Fetching 435/500: TGT
# Fetching 436/500: TEL
# Fetching 437/500: TDY
# Fetching 438/500: TER
# Fetching 439/500: TSLA
# Fetching 440/500: TXN
# Fetching 441/500: TPL
# Fetching 442/500: TXT
# Fetching 443/500: TMO
# Fetching 444/500: TJX
# Fetching 445/500: TKO
# Fetching 446/500: TSCO
# Fetching 447/500: TT
# Fetching 448/500: TDG
# Fetching 449/500: TRV
# Fetching 450/500: TRMB
# Fetching 451/500: TFC
# Fetching 452/500: TYL
# Fetching 453/500: TSN
# Fetching 454/500: USB
# Fetching 455/500: UBER
# Fetching 456/500: UDR
# Fetching 457/500: ULTA
# Fetching 458/500: UNP
# Fetching 459/500: UAL
# Fetching 460/500: UPS
# Fetching 461/500: URI
# Fetching 462/500: UNH
# Fetching 463/500: UHS
# Fetching 464/500: VLO
# Fetching 465/500: VTR
# Fetching 466/500: VLTO
# Fetching 467/500: VRSN
# Fetching 468/500: VRSK
# Fetching 469/500: VZ
# Fetching 470/500: VRTX
# Fetching 471/500: VTRS
# Fetching 472/500: VICI
# Fetching 473/500: V
# Fetching 474/500: VST
# Fetching 475/500: VMC
# Fetching 476/500: WRB
# Fetching 477/500: GWW
# Fetching 478/500: WAB
# Fetching 479/500: WBA
# Fetching 480/500: WMT
# Fetching 481/500: DIS
# Fetching 482/500: WBD
# Fetching 483/500: WM
# Fetching 484/500: WAT
# Fetching 485/500: WEC
# Fetching 486/500: WFC
# Fetching 487/500: WELL
# Fetching 488/500: WST
# Fetching 489/500: WDC
# Fetching 490/500: WY
# Fetching 491/500: WSM
# Fetching 492/500: WMB
# Fetching 493/500: WTW
# Fetching 494/500: WDAY
# Fetching 495/500: WYNN
# Fetching 496/500: XEL
# Fetching 497/500: XYL
# Fetching 498/500: YUM
# Fetching 499/500: ZBH
# Fetching 500/500: ZTS

# %%
def backtest_risk_adj_momentum(price_data, top_n=3, months=60, momentum_days=60, vol_days=30):
    monthly_returns = []
    monthly_dates = []

    for i in range(months):
        current_start = price_data.index[0] + timedelta(days=i*30)
        current_end = current_start + timedelta(days=30)

        lookback = price_data.loc[:current_start]
        if lookback.shape[0] < momentum_days + 1:
            continue

        momentum = lookback.pct_change(momentum_days).iloc[-1]
        volatility = lookback.pct_change().rolling(vol_days).std().iloc[-1]
        scores = momentum / volatility

        top_tickers = scores.dropna().nlargest(top_n).index
        forward = price_data.loc[current_start:current_end]

        if forward.empty or not all(t in forward.columns for t in top_tickers):
            continue

        forward_returns = forward[top_tickers].pct_change().mean(axis=1)
        monthly_return = (1 + forward_returns).prod() - 1

        monthly_dates.append(current_end)
        monthly_returns.append(monthly_return)

    cumulative_return = (1 + pd.Series(monthly_returns)).prod() - 1

    print("Monthly Performance:")
    for d, r in zip(monthly_dates, monthly_returns):
        print(f"{d.strftime('%Y-%m-%d')}: {r:.2%}")

    print(f"\nCumulative Return (5 Years): {cumulative_return:.2%}")
    return monthly_dates, monthly_returns, cumulative_return

# %%
# Run full backtest
dates, rets, total_ret = backtest_risk_adj_momentum(price_data)

# Calculate current year performance
def calc_ytd(dates, rets):
    year = datetime.now().year
    ytd = [r for d, r in zip(dates, rets) if d.year == year]
    ytd_return = (1 + pd.Series(ytd)).prod() - 1
    print(f"\nYTD Return ({year}): {ytd_return:.2%}")
    return ytd_return

# Get YTD performance
calc_ytd(dates, rets)
# Out:
# Monthly Performance:
# 2020-10-28: -9.60%
# 2020-11-27: 20.29%
# 2020-12-27: 4.24%
# 2021-01-26: 7.89%
# 2021-02-25: 3.01%
# 2021-03-27: 7.48%
# 2021-04-26: 2.86%
# 2021-05-26: -1.57%
# 2021-06-25: -0.89%
# 2021-07-25: 5.78%
# 2021-08-24: 4.95%
# 2021-09-23: 0.61%
# 2021-10-23: -3.34%
# 2021-11-22: 5.26%
# 2021-12-22: 4.76%
# 2022-01-21: -12.20%
# 2022-02-20: 1.98%
# 2022-03-22: -0.35%
# 2022-04-21: 6.58%
# 2022-05-21: -18.26%
# 2022-06-20: -14.18%
# 2022-07-20: 6.65%
# 2022-08-19: 8.00%
# 2022-09-18: -3.65%
# 2022-10-18: -13.72%
# 2022-11-17: 18.79%
# 2022-12-17: -7.27%
# 2023-01-16: 5.43%
# 2023-02-15: 3.03%
# 2023-03-17: -5.97%
# 2023-04-16: 8.63%
# 2023-05-16: -0.93%
# 2023-06-15: 0.94%
# 2023-07-15: -2.44%
# 2023-08-14: -7.63%
# 2023-09-13: 3.93%
# 2023-10-13: 1.15%
# 2023-11-12: -5.00%
# 2023-12-12: 7.66%
# 2024-01-11: 1.73%
# 2024-02-10: 0.43%
# 2024-03-11: 0.70%
# 2024-04-10: -5.54%
# 2024-05-10: -0.61%
# 2024-06-09: -5.17%
# 2024-07-09: -3.16%
# 2024-08-08: -0.62%
# 2024-09-07: 2.70%
# 2024-10-07: 0.44%
# 2024-11-06: -3.56%
# 2024-12-06: 6.69%
# 2025-01-05: -6.16%
# 2025-02-04: 7.85%
# 2025-03-06: -5.83%
# 2025-04-05: -6.28%
# 2025-05-05: 5.25%
# 2025-06-04: -1.60%
#
# Cumulative Return (5 Years): 5.88%
#
# YTD Return (2025): -7.50%
# np.float64(-0.07495895641653905)
